# %% [markdown]
# # Data Science Life Cycle

# %% [markdown]
# 1. Data Analysis
# 2. Feature Engineering
# 3. Feature Selection
# 4. ML Model

# %%
import numpy as np

data = {
    "Customar id": [0,1,2,3],
    "Food": ["Apple","Orange","Banana","Mango"],
    "Review": [1,4,2,5]
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(data)
df
# Out:
#    Customar id    Food  Review
# 0            0   Apple       1
# 1            1  Orange       4
# 2            2  Banana       2
# 3            3   Mango       5

# %%
df.dtypes
# Out:
# Customar id     int64
# Food           object
# Review          int64
# dtype: object

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.shape
# Out:
# (891, 12)

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df["Name"]
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name'].head() # series data
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
type(df['Name'])
# Out:
# pandas.core.series.Series

# %%
df[['Name','Pclass']] # Data frame
# Out:
#                                                   Name  Pclass
# 0                              Braund, Mr. Owen Harris       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2                               Heikkinen, Miss. Laina       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4                             Allen, Mr. William Henry       3
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas       2
# 887                       Graham, Miss. Margaret Edith       1
# 888           Johnston, Miss. Catherine Helen "Carrie"       3
# 889                              Behr, Mr. Karl Howell       1
# 890                                Dooley, Mr. Patrick       3
#
# [891 rows x 2 columns]

# %%
df[['Name','Pclass']].head() # Data frame
# Out:
#                                                 Name  Pclass
# 0                            Braund, Mr. Owen Harris       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2                             Heikkinen, Miss. Laina       3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4                           Allen, Mr. William Henry       3

# %%
type(df[['Name','Pclass']])
# Out:
# pandas.core.frame.DataFrame

# %%
df['Name'][df['Pclass']== 1]
# Out:
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 6                                McCarthy, Mr. Timothy J
# 11                              Bonnell, Miss. Elizabeth
# 23                          Sloper, Mr. William Thompson
#                              ...
# 871     Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 872                             Carlsson, Mr. Frans Olof
# 879        Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 887                         Graham, Miss. Margaret Edith
# 889                                Behr, Mr. Karl Howell
# Name: Name, Length: 216, dtype: object

# %%
df[['Name','Sex','Pclass']][df['Pclass']== 1]
# Out:
#                                                   Name     Sex  Pclass
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female       1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female       1
# 6                              McCarthy, Mr. Timothy J    male       1
# 11                            Bonnell, Miss. Elizabeth  female       1
# 23                        Sloper, Mr. William Thompson    male       1
# ..                                                 ...     ...     ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female       1
# 872                           Carlsson, Mr. Frans Olof    male       1
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female       1
# 887                       Graham, Miss. Margaret Edith  female       1
# 889                              Behr, Mr. Karl Howell    male       1
#
# [216 rows x 3 columns]

# %%
df[['Name','Sex','Pclass']][(df['Pclass'] == 1) & (df['Sex']=='male')]
# Out:
#                                      Name   Sex  Pclass
# 6                 McCarthy, Mr. Timothy J  male       1
# 23           Sloper, Mr. William Thompson  male       1
# 27         Fortune, Mr. Charles Alexander  male       1
# 30               Uruchurtu, Don. Manuel E  male       1
# 34                Meyer, Mr. Edgar Joseph  male       1
# ..                                    ...   ...     ...
# 839                  Marechal, Mr. Pierre  male       1
# 857                Daly, Mr. Peter Denis   male       1
# 867  Roebling, Mr. Washington Augustus II  male       1
# 872              Carlsson, Mr. Frans Olof  male       1
# 889                 Behr, Mr. Karl Howell  male       1
#
# [122 rows x 3 columns]

# %%
df['Name'][df['Pclass'] == 1].count()
# Out:
# 216

# %%
df['Name'][df['Pclass'] > 1].count()
# Out:
# 675

# %%
df[df['Name'] ==  "Behr, Mr. Karl Howell"]
# Out:
#      PassengerId  Survived  Pclass                   Name   Sex   Age  SibSp  \
# 889          890         1       1  Behr, Mr. Karl Howell  male  26.0      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 889      0  111369  30.0  C148        C

# %%
df[df['Sex'] == 'male']
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df[df['Sex']== 'male'].count()
# Out:
# PassengerId    577
# Survived       577
# Pclass         577
# Name           577
# Sex            577
# Age            453
# SibSp          577
# Parch          577
# Ticket         577
# Fare           577
# Cabin          107
# Embarked       577
# dtype: int64

# %%
sorted(df['Pclass'].unique())
# Out:
# [1, 2, 3]

# %%
df[['Name','Pclass','Age']].head()
# Out:
#                                                 Name  Pclass   Age
# 0                            Braund, Mr. Owen Harris       3  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...       1  38.0
# 2                             Heikkinen, Miss. Laina       3  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  35.0
# 4                           Allen, Mr. William Henry       3  35.0

# %%
df[df['Name'] == 'Waelens, Mr. Achille']
# Out:
#     PassengerId  Survived  Pclass                  Name   Sex   Age  SibSp  \
# 80           81         0       3  Waelens, Mr. Achille  male  22.0      0
#
#     Parch  Ticket  Fare Cabin Embarked
# 80      0  345767   9.0   NaN        S

# %%
max(df['Age'])
# Out:
# 80.0

# %%
min(df['Age'])
# Out:
# 0.42

# %%
df[df['Age'] == max(df['Age'])]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#       Sex   Age  SibSp  Parch Ticket  Fare Cabin Embarked
# 630  male  80.0      0      0  27042  30.0   A23        S

# %%
df['Name'][df['Age'] == max(df['Age'])]
# Out:
# 630    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %%
df[['Name','Pclass','Fare']][df['Age'] == max(df['Age'])]
# Out:
#                                      Name  Pclass  Fare
# 630  Barkworth, Mr. Algernon Henry Wilson       1  30.0

# %%
df[(df['Sex'] == 'female') & (df['Age'] <=38)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 874          875         1       2
# 875          876         1       3
# 880          881         1       2
# 882          883         0       3
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Name'][(df['Sex'] == 'female') & (df['Age'] <=25)].count()
# Out:
# 122

# %%
df[['Name','Pclass','Sex']][(df['Age']>=20) & (df['Age']<=50)]
# Out:
#                                                   Name  Pclass     Sex
# 0                              Braund, Mr. Owen Harris       3    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...       1  female
# 2                               Heikkinen, Miss. Laina       3  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female
# 4                             Allen, Mr. William Henry       3    male
# ..                                                 ...     ...     ...
# 884                             Sutehall, Mr. Henry Jr       3    male
# 885               Rice, Mrs. William (Margaret Norton)       3  female
# 886                              Montvila, Rev. Juozas       2    male
# 889                              Behr, Mr. Karl Howell       1    male
# 890                                Dooley, Mr. Patrick       3    male
#
# [486 rows x 3 columns]

# %%
df[['Name','Pclass','Sex']][(df['Age']>=20) & (df['Age']<=50)].count()
# Out:
# Name      486
# Pclass    486
# Sex       486
# dtype: int64
